# %% [markdown]
# <font face="Roboto Slab" size=10 color=#000000 >Project ECE143
#
# <font face="Georgia" size=5 color=#000000 >Group 16
#
# <font face="Georgia" size=5 color=#000000 >Members: Shah, Sneh Raj / Lin, Li-Kuo / Li, Ke  / Mei, Hao

# %% [markdown]
# <font face="Roboto Slab" size=6 color=#000000 >Objectives
#
# <font face="Georgia" size=5 color=#000000 >Analyse different kind of gun shooting violence
#
# <font face="Georgia" size=4 color=#000000 >1.Mass shooting
#
# <font face="Georgia" size=4 color=#000000 >2.Officer shooting
#
# <font face="Georgia" size=4 color=#000000 >3.School shooting

# %%
import matplotlib.pyplot as plt
import numpy as np
from gundata import gundata
import pandas as pd
from main import *

# %%
data1 = data("Mass_Shootings")
data2 = data("Officers_Shootings")
data3 = data("School_Schootings")

# %% [markdown]
# <font face="Roboto Slab" size=6 color=#000000 >The number of occurance changes over Time

# %%
data1.plot_incidence_and_casualties_per_year(method='bar')

# %% [markdown]
# <font face="Georgia" size=5 color=#000000 >The number of mass shootings reached its peak in 2016, then droped

# %%
data2.plot_incidence_and_casualties_per_year(method='bar')

# %% [markdown]
# <font face="Georgia" size=5 color=#000000 >The number of officer shootings stayed high from 2015-2017, then had a slight drop

# %%
data3.plot_incidence_per_year(method='bar')

# %% [markdown]
# <font face="Georgia" size=5 color=#000000 >The number of school shootings had a sharp increase in 2018

# %% [markdown]
# <font face="Georgia" size=5 color=#000000 >BBC: 2018 'worst year for US school shootings'
#
# <font face="Georgia" size=5 color=#000000 >We may ask why?

# %%
data3.plot_school_type()

# %% [markdown]
# <font face="Georgia" size=5 color=#000000 >High school is the most common place of school shooting, followed by college/university, elementary school, middle school and K-12 school.

# %%
data3.plot_school_type_per_year()

# %% [markdown]
# <font face="Georgia" size=5 color=#000000 >The number of school shooting in college/university did not increase at all, on the contrary, it decreased nearly 30% percent. But the other four type all had conspicuously increase by 126%, 125%, 64%, 50%.

# %%
data3.plot_incidence_per_month()

# %% [markdown]
# <font face="Roboto Slab" size=6 color=#000000 >State distribution

# %%
data1.plot_state_year()

# %% [markdown]
# <font face="Georgia" size=5 color=#000000 >Top 5
#
#    <font face="Georgia" size=5 color=#000000 >1.California: 11.3%
#
#    <font face="Georgia" size=5 color=#000000 >2.Illinois: 9.58%
#
#    <font face="Georgia" size=5 color=#000000 >3.Florida: 7.46%
#
#    <font face="Georgia" size=5 color=#000000 >4.Texas: 6.12%
#
#    <font face="Georgia" size=5 color=#000000 >5.Georgia: 4.29%

# %%
data2.plot_state_year()

# %% [markdown]
# <font face="Georgia" size=5 color=#000000 >Top 5
#
#    <font face="Georgia" size=5 color=#000000 >1.Texas: 9.04%
#
#    <font face="Georgia" size=5 color=#000000 >2.California: 8.52%
#
#    <font face="Georgia" size=5 color=#000000 >3.Florida: 5.47%
#
#    <font face="Georgia" size=5 color=#000000 >4.Georgia: 5.27%
#
#    <font face="Georgia" size=5 color=#000000 >5.Illinois: 3.84%

# %%
data3.plot_state_year()

# %% [markdown]
# <font face="Georgia" size=5 color=#000000 >Top 5
#
#    <font face="Georgia" size=5 color=#000000 >1.Texas: 9.65%
#
#    <font face="Georgia" size=5 color=#000000 >2.Georgia: 8.52%
#
#    <font face="Georgia" size=5 color=#000000 >3.Florida: 5.47%
#
#    <font face="Georgia" size=5 color=#000000 >4.California: 5.27%
#
#    <font face="Georgia" size=5 color=#000000 >5.Ohio: 3.84%
