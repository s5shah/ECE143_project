# %% [markdown]
# # Project ECE143

# %%
import matplotlib.pyplot as plt
import numpy as np
from gundata import gundata
import pandas as pd
from main import *

# %%
data1 = data("Mass_Shootings")
data2 = data("Officers_Shootings")
data3 = data("School_Schootings")

# %%
data1.plot_incidence_per_year('bar')

# %%
data2.plot_incidence_per_year('bar')

# %%
data3.plot_incidence_per_year('bar')

# %%
data1.plot_state_year()

# %%
data2.plot_state_year()

# %%
data3.plot_state_year()
